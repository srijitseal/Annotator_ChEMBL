# %%
import pandas as pd
from chembl_structure_pipeline import standardizer
from chembl_structure_pipeline import checker
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem import MolStandardize

# %%
df1 = pd.read_csv("data/CDRP_top40.txt")
df2 = pd.read_csv("data/JUMP_top40.txt")
df3 = pd.read_csv("data/lincs_top40.txt")

# %%
df1 = df1[["Smiles"]]
df1
# Out:
#                                                Smiles
# 0   COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 1   OC[C@@H]1O[C@H](CCNC(=O)Cc2ccccn2)CC[C@H]1NC(=...
# 2   CC(C)C#Cc1ccc2c(O[C@H](CN(C)C(=O)c3ccncc3)[C@H...
# 3                [O-][N+](=O)c1ccc2oc(nc2c1)-c1ccccc1
# 4   C[C@@H](CO)N1C[C@H](C)[C@@H](CN(C)C(=O)Nc2cccc...
# 5   COC(=O)C[C@@H]1C[C@H]2[C@H](Oc3ccc(NC(=O)C4CCO...
# 6                          CCSc1nn2c(nc3ccccc3c2=O)s1
# 7   Cc1ccccc1S(=O)(=O)NCC[C@@H]1CC[C@@H](NC(=O)Nc2...
# 8                   Oc1ccc(C(=O)Cc2c(F)cccc2Cl)c(O)c1
# 9   CC(C)NC(=O)N[C@H]1CC[C@@H](CC(=O)NC2Cc3ccccc3C...
# 10                       CCc1ccc(\C=C(\C#N)C(N)=S)cc1
# 11  CCCN(C)C[C@H]1OCCCC[C@@H](C)Oc2ccc(NS(=O)(=O)c...
# 12  CC(C)NC(=O)N[C@H]1CC[C@@H](CC(=O)NC2Cc3ccccc3C...
# 13                      Clc1ccc(NC(=S)NCCc2ccccc2)cc1
# 14  Cc1cc(C)n(CC(O)CN(c2ccc(C)cc2)S(=O)(=O)c2ccc3c...
# 15                 O=C(N1C(=O)c2cccc3cccc1c23)c1ccco1
# 16                   Brc1ccc(CSc2ccc(nn2)-c2ccco2)cc1
# 17  Cc1ccc(cc1)S(=O)(=O)NCC[C@@H]1CC[C@H](NC(=O)c2...
# 18  CCCNC(=O)Nc1ccc2c(OC[C@@H](C)NC[C@@H](C)[C@H](...
# 19  CCCNC(=O)C[C@@H]1CC[C@H]2[C@H](COc3ccc(NC(=O)c...
# 20  Cc1noc(C)c1NC(=O)N[C@@H]1CC[C@@H](CC(=O)NCc2cc...
# 21             CCC(=O)c1cn(CC(=O)Nc2ccccc2F)c2ccccc12
# 22           Cc1cc(Br)ccc1NC(=O)CCN1C(=O)c2ccncc2C1=O
# 23  COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 24  CC(C)NC(=O)N[C@@H]1CC[C@H](CC(=O)NC2Cc3ccccc3C...
# 25  OC[C@@H]1O[C@@H](CC(=O)N2CCN(CC2)c2ccccc2)C=C[...
# 26  OC[C@H]1O[C@H](CCNS(=O)(=O)Cc2ccccc2)CC[C@@H]1...
# 27  C[C@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2cccnc...
# 28  CC(C)NC(=O)N[C@@H]1CC[C@H](CC(=O)NC2Cc3ccccc3C...
# 29  CC(C)NC(=O)NCC[C@@H]1CC[C@@H](NC(=O)c2ccc(F)cc...
# 30  CO[C@@H]1CN(C)C(=O)c2ccc(NS(C)(=O)=O)cc2OC[C@H...
# 31   CCNC(=O)C[C@H]1CC[C@@H](NC(=O)C2CC2)[C@@H](CO)O1
# 32  OC[C@@H]1O[C@H](CCNS(=O)(=O)Cc2ccccc2)CC[C@@H]...
# 33  CO[C@@H]1CN(C)C(=O)c2cc(NS(C)(=O)=O)ccc2OC[C@H...
# 34  OC[C@H]1O[C@@H](CCNS(=O)(=O)Cc2ccccc2)CC[C@H]1...
# 35               Clc1ccc(C(=O)NNC(=N)Cn2cncn2)c(Cl)c1
# 36  CNC[C@@H]1Oc2ccc(NC(=O)c3ccncc3)cc2CC(=O)N(C[C...
# 37  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)CC2CC2)OCCCC...
# 38  CC(C)NC(=O)N[C@H]1C=C[C@@H](CC(=O)N2CCCCC2)O[C...
# 39                    CCCCCC(=O)NNC1=NCC(Cc2ccccc2)S1

# %%
RDLogger.DisableLog('rdApp.*')  
def inchitosmiles(smiles):
    
    try:
        # Read SMILES and convert it to RDKit mol object
        mol = Chem.MolFromInchi(smiles)
        inchi_standardized = Chem.MolToSmiles(mol)

        return inchi_standardized
    
    except:
        return "Cannot_do"
    
df2["Smiles"] = df2["Metadata_InChI"].apply(inchitosmiles)
df2 = df2[["Smiles"]]
df2
# Out:
#                                                Smiles
# 0   Cc1cc(C)cc(N(CC(=O)O)S(=O)(=O)c2ccc3[nH]c(=O)c...
# 1                 COc1ccc(C)cc1N=C(O)c1cncn1-c1ccccc1
# 2                     N#CC(C#N)=NNc1ccc(OC(F)(F)F)cc1
# 3      CN(C)S(=O)(=O)N1CCN(c2ccc([N+](=O)[O-])cc2)CC1
# 4                 COc1ccc(CCS(=O)(=O)NCC2(O)CCOC2)cc1
# 5             CC(C)n1cc(C(=N)NO)c(=O)n(Cc2ccccc2)c1=O
# 6                    Cc1cc(C(=O)N2CCN=C(O)C2(C)C)nn1C
# 7   COc1ccc(Cn2cnc3c(NS(=O)(=O)c4c(Cl)cc(Cl)cc4Cl)...
# 8             Cc1nn(CC=NC2NCN=C3NC=C(O)N=C32)c(C)c1Cl
# 9            COc1cc2c(cc1OC)C(=NC(C)C(=O)O)NC(C)(C)C2
# 10  CN(C)S(=O)(=O)N1CCN(c2ccc([N+](=O)[O-])c(NC3CC...
# 11     O=C1OC(C(O)=Nc2ccc(Cl)c(C(F)(F)F)c2)Cc2ccccc21
# 12                 Cc1cc(S(=O)(=O)NC2CCC(O)=NC2)ccc1F
# 13                      Cc1nc(C)c(-c2cc[nH]c(=N)n2)s1
# 14                   Cc1cc(C(=O)NCc2ccc(C3CC3)nc2)no1
# 15               Cn1c(=O)c2c(NCc3ccccn3)ccnc2n(C)c1=O
# 16            CCCCCN1CCN(C)C2(CCC(=O)N(CC(=O)O)CC2)C1
# 17   CCc1ccc(N2CC(c3nnc(N=C(O)COc4ccccc4)s3)CC2=O)cc1
# 18                      O=S(=O)(Cc1ccccc1)c1c[nH]nc1O
# 19  COc1cc(NS(=O)(=O)c2ccc(NC(=O)c3c(OC)cccc3OC)cc...
# 20          CCOC(=O)C1C(=O)C(=Cc2ccccc2)SC1=Nc1ccccc1
# 21                   N=C1Nc2ccccc2C12C1CC3CC(C1)CC2C3
# 22  O=C(c1cccnc1)C1C(c2ccc(Cl)cc2)C2CSCN2C12C(O)=N...
# 23   O=[N+]([O-])c1cccc(N=C(O)CCN2CCN(c3ncccn3)CC2)c1
# 24  COc1ccccc1Oc1ccc(C(F)(F)F)cc1N=C(O)N=C(O)c1ccc...
# 25     CN(C)CCOc1ccccc1CN1CCc2cc(S(=O)(=O)N(C)C)ccc21
# 26  COc1ccc(N2C(=O)CC2(C(O)=Nc2c(C)cccc2C)c2ccccc2...
# 27  Nc1ccc(Oc2ccc3nc(-c4ccc(F)cc4)c(-c4ccc(F)cc4)n...
# 28        c1ccc(-c2nc(Cn3nnc4ccccc43)sc2-c2ccccc2)cc1
# 29         COc1ccc(C=CC(=O)c2c(C)[nH]c3ccccc3c2=N)cc1
# 30  CN1CCN(c2nc(-c3cccc(C(F)(F)F)c3)cc(-c3ccc(Cl)c...
# 31            COc1ccc(Cl)cc1S(=O)(=O)N1CCC(c2ccsc2)C1
# 32  CCn1cc(-c2cc(C(=O)N(C)Cc3ccnn3C)c3ccccc3n2)c(C)n1
# 33   Cc1ccsc1CN(Cc1ccccc1)C(=O)CN(C(=O)C(C)(C)C)C1CC1
# 34           O=C(N=C(Cc1cccs1)C(=O)N1CCCCCC1)c1ccccc1
# 35      Cn1nc(-c2csc(S(=O)(=O)Nc3cc(F)ccc3F)c2)ccc1=O
# 36           Cc1cccc(CCC(=O)N2CCCC(Oc3ncc(F)cn3)C2)c1
# 37    CCN1C(=O)COc2ccc(-c3nc(NC(=O)c4ccncc4)sc3C)cc21
# 38            CN(Cc1noc2c1CCCC2)C(=O)c1ccc2ccn(C)c2c1
# 39  COc1ccc(CN=C(O)c2nn[nH]c2Nc2ccc(Oc3ccccc3)cc2)cc1

# %%
df3 = df3[["Smiles"]]
df3
# Out:
#                                                Smiles
# 0           CCCCCCCCCCC(C)(C)C(=O)Nc1c(OC)cc(OC)cc1OC
# 1                           CC(N)C12CC3CC(CC(C3)C1)C2
# 2                       CCOC(=O)Nc1c[n+](no1)N1CCOCC1
# 3                     Nc1ccc(cc1)S(=O)(=O)c1ccc(N)cc1
# 4   COc1ccc2C[C@H]3N(C)CCc4cc(OC)c(Oc5c6OCOc6cc6CC...
# 5   COc1cc2nccc(Oc3ccc(NC(=O)Nc4cc(C)on4)c(Cl)c3)c...
# 6   COC([C@H](Oc1nc(C)cc(C)n1)C(O)=O)(c1ccccc1)c1c...
# 7           COc1ccc(cc1OC1CCCC1)C1(CCC(CC1)C(O)=O)C#N
# 8       CCOC(=O)c1ncc2[nH]c3ccc(OCc4ccccc4)cc3c2c1COC
# 9             CN(C)CCCC1(OCc2cc(ccc12)C#N)c1ccc(F)cc1
# 10                     OC(=O)CCCc1ccc(cc1)N(CCCl)CCCl
# 11       Cc1ccc(cc1)C(=O)c1cc(O)c(O)c(c1)[N+]([O-])=O
# 12  CCc1cc2CC(Cc2cc1CC)NC[C@H](O)c1ccc(O)c2[nH]c(=...
# 13            CN(C)CCCC1(OCc2cc(ccc12)C#N)c1ccc(F)cc1
# 14  Nc1nc(=O)c2nc(CNc3ccc(cc3)C(=O)N[C@@H](CCC(O)=...
# 15  CN1[C@H]2C[C@H](O)[C@H]1C[C@H](C2)OC(=O)[C@H](...
# 16        COc1cc(cc(OC)c1OC)C(=O)NCc1ccc(OCCN(C)C)cc1
# 17          NC(=O)N1C(=O)C(C(=O)c2cccs2)c2cc(Cl)ccc12
# 18               OC(=O)c1cccc(c1)-c1noc(n1)-c1ccccc1F
# 19                       Cn1cnc2n(C)c(=O)n(C)c(=O)c12
# 20          CN1C(C(=O)Nc2ccccn2)C(=O)c2ccccc2S1(=O)=O
# 21  CCCC[C@H](NC(=O)[C@@H]1[C@@H]2[C@H](CN1C(=O)[C...
# 22          CN1C(C(=O)Nc2ccccn2)C(=O)c2ccccc2S1(=O)=O
# 23  Nc1nccc(Oc2ccc(NC(=O)c3c[nH]cc(-c4ccc(F)cc4)c3...
# 24         CCC(=O)N(c1ccccc1)C1(COC)CCN(CCc2cccs2)CC1
# 25         CCOC(=O)c1cncn1[C@@H](C)c1ccccc1 |&1:10,r|
# 26                                    CCCC(CCC)C(O)=O
# 27                     OC(=O)Cc1ccccc1Nc1c(Cl)cccc1Cl
# 28                          CC(N)C12CC3CC(CC(C3)C1)C2
# 29  COc1ccc(CCN(C)CCCOc2ccc(cc2)S(=O)(=O)c2c(C(C)C...
# 30  Cc1ccc(cc1)S(=O)(=O)Nc1nc2ccccc2nc1Nc1ccc2nsnc2c1
# 31  C[C@H]1O[C@H](O[C@@H]2[C@@H](CO)O[C@H](O[C@@H]...
# 32            CN(C)CCCC1(OCc2cc(ccc12)C#N)c1ccc(F)cc1
# 33                            CCN(CC)c1cc(C)nc2ncnn12
# 34                 OC(Cn1cncn1)(Cn1cncn1)c1ccc(F)cc1F
# 35                    CCOC(=O)c1cncn1[C@H](C)c1ccccc1
# 36  CC(=O)C[C@@H](c1ccc(cc1)[N+]([O-])=O)c1c(O)c2c...
# 37                       CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# 38                      OC(=O)c1ccccc1OC(=O)c1ccccc1O
# 39                             Oc1c(I)cc(Cl)c2cccnc12
# 40   Cn1cc(c(n1)-c1ccc(OCc2ccc3ccccc3n2)cc1)-c1ccncc1

# %%
df = pd.concat([df1, df2, df3]).drop_duplicates(keep="first").reset_index(drop=True)
df
# Out:
#                                                 Smiles
# 0    COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 1    OC[C@@H]1O[C@H](CCNC(=O)Cc2ccccn2)CC[C@H]1NC(=...
# 2    CC(C)C#Cc1ccc2c(O[C@H](CN(C)C(=O)c3ccncc3)[C@H...
# 3                 [O-][N+](=O)c1ccc2oc(nc2c1)-c1ccccc1
# 4    C[C@@H](CO)N1C[C@H](C)[C@@H](CN(C)C(=O)Nc2cccc...
# ..                                                 ...
# 112  CC(=O)C[C@@H](c1ccc(cc1)[N+]([O-])=O)c1c(O)c2c...
# 113                       CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# 114                      OC(=O)c1ccccc1OC(=O)c1ccccc1O
# 115                             Oc1c(I)cc(Cl)c2cccnc12
# 116   Cn1cc(c(n1)-c1ccc(OCc2ccc3ccccc3n2)cc1)-c1ccncc1
#
# [117 rows x 1 columns]

# %%
def standardize_chembl(smiles):
    
    try:
        # Read SMILES and convert it to RDKit mol object
        mol = Chem.MolFromSmiles(smiles)

        desalter = MolStandardize.fragment.LargestFragmentChooser()
        std1_mol = standardizer.standardize_mol(mol)
        desalt_mol = desalter.choose(std1_mol)
        std2_mol = standardizer.standardize_mol(desalt_mol)
        smiles_standardized = Chem.MolToSmiles(std2_mol)

        return smiles_standardized
    
    except:
        return "Cannot_do"

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True, nb_workers=80)
# Out:
# INFO: Pandarallel will run on 80 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
import pandas as pd 
from tqdm import tqdm 
import time 

RDLogger.DisableLog('rdApp.info')  
tqdm.pandas()

# %%
df["Standardized_SMILES_chembl"] = df["Smiles"].parallel_apply(standardize_chembl)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=2), Label(value='0 / 2'))), HBox(c…

# %%
RDLogger.DisableLog('rdApp.*')  
def smiles_to_inchi(smiles):
    
    try:
        # Read SMILES and convert it to RDKit mol object
        mol = Chem.MolFromSmiles(smiles)
        inchi_standardized = Chem.MolToInchi(mol)

        return inchi_standardized
    
    except:
        return "Cannot_do"

# %%
df["Standardized_InChI_chembl"] = df["Standardized_SMILES_chembl"].parallel_apply(smiles_to_inchi)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=2), Label(value='0 / 2'))), HBox(c…

# %%
df
# Out:
#                                                 Smiles  \
# 0    COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 1    OC[C@@H]1O[C@H](CCNC(=O)Cc2ccccn2)CC[C@H]1NC(=...
# 2    CC(C)C#Cc1ccc2c(O[C@H](CN(C)C(=O)c3ccncc3)[C@H...
# 3                 [O-][N+](=O)c1ccc2oc(nc2c1)-c1ccccc1
# 4    C[C@@H](CO)N1C[C@H](C)[C@@H](CN(C)C(=O)Nc2cccc...
# ..                                                 ...
# 112  CC(=O)C[C@@H](c1ccc(cc1)[N+]([O-])=O)c1c(O)c2c...
# 113                       CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# 114                      OC(=O)c1ccccc1OC(=O)c1ccccc1O
# 115                             Oc1c(I)cc(Cl)c2cccnc12
# 116   Cn1cc(c(n1)-c1ccc(OCc2ccc3ccccc3n2)cc1)-c1ccncc1
#
#                             Standardized_SMILES_chembl  \
# 0    COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 1    O=C(Cc1ccccn1)NCC[C@@H]1CC[C@@H](NC(=O)c2ccccc...
# 2    CC(C)C#Cc1ccc2c(c1)O[C@H](CN(C)C(=O)c1ccncc1)[...
# 3                 O=[N+]([O-])c1ccc2oc(-c3ccccc3)nc2c1
# 4    C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# ..                                                 ...
# 112  CC(=O)C[C@@H](c1ccc([N+](=O)[O-])cc1)c1c(O)c2c...
# 113                       CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# 114                      O=C(Oc1ccccc1C(=O)O)c1ccccc1O
# 115                             Oc1c(I)cc(Cl)c2cccnc12
# 116   Cn1cc(-c2ccncc2)c(-c2ccc(OCc3ccc4ccccc4n3)cc2)n1
#
#                              Standardized_InChI_chembl
# 0    InChI=1S/C22H28N4O5/c1-30-17-7-5-15(6-8-17)25-...
# 1    InChI=1S/C22H26FN3O4/c23-18-7-2-1-6-17(18)22(2...
# 2    InChI=1S/C26H33N3O5S/c1-18(2)6-7-21-8-9-25-23(...
# 3    InChI=1S/C13H8N2O3/c16-15(17)10-6-7-12-11(8-10...
# 4    InChI=1S/C23H33FN6O4/c1-16-11-30(17(2)14-31)22...
# ..                                                 ...
# 112  InChI=1S/C19H15NO6/c1-11(21)10-15(12-6-8-13(9-...
# 113  InChI=1S/C12H15ClO3/c1-4-15-11(14)12(2,3)16-10...
# 114  InChI=1S/C14H10O5/c15-11-7-3-1-5-9(11)14(18)19...
# 115  InChI=1S/C9H5ClINO/c10-6-4-7(11)9(13)8-5(6)2-1...
# 116  InChI=1S/C25H20N4O/c1-29-16-23(18-12-14-26-15-...
#
# [117 rows x 3 columns]

# %%
RDLogger.DisableLog('rdApp.*')  
def smiles_to_inchikey(smiles):
    
    try:
        # Read SMILES and convert it to RDKit mol object
        mol = Chem.MolFromSmiles(smiles)
        inchi_standardized = Chem.MolToInchiKey(mol)

        return inchi_standardized
    
    except:
        return "Cannot_do"

# %%
df["Standardized_InChIKey_chembl"] = df["Standardized_SMILES_chembl"].parallel_apply(smiles_to_inchikey)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=2), Label(value='0 / 2'))), HBox(c…

# %%
df.Smiles == df.Standardized_SMILES_chembl
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113     True
# 114    False
# 115     True
# 116    False
# Length: 117, dtype: bool

# %%
df.to_csv("mitotox.csv.gz", index=False, compression="gzip")

# %%
import pandas as pd
df = pd.read_csv("mitotox.csv.gz", compression="gzip")
df
# Out:
#                                                 Smiles  \
# 0    COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 1    OC[C@@H]1O[C@H](CCNC(=O)Cc2ccccn2)CC[C@H]1NC(=...
# 2    CC(C)C#Cc1ccc2c(O[C@H](CN(C)C(=O)c3ccncc3)[C@H...
# 3                 [O-][N+](=O)c1ccc2oc(nc2c1)-c1ccccc1
# 4    C[C@@H](CO)N1C[C@H](C)[C@@H](CN(C)C(=O)Nc2cccc...
# ..                                                 ...
# 112  CC(=O)C[C@@H](c1ccc(cc1)[N+]([O-])=O)c1c(O)c2c...
# 113                       CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# 114                      OC(=O)c1ccccc1OC(=O)c1ccccc1O
# 115                             Oc1c(I)cc(Cl)c2cccnc12
# 116   Cn1cc(c(n1)-c1ccc(OCc2ccc3ccccc3n2)cc1)-c1ccncc1
#
#                             Standardized_SMILES_chembl  \
# 0    COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 1    O=C(Cc1ccccn1)NCC[C@@H]1CC[C@@H](NC(=O)c2ccccc...
# 2    CC(C)C#Cc1ccc2c(c1)O[C@H](CN(C)C(=O)c1ccncc1)[...
# 3                 O=[N+]([O-])c1ccc2oc(-c3ccccc3)nc2c1
# 4    C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# ..                                                 ...
# 112  CC(=O)C[C@@H](c1ccc([N+](=O)[O-])cc1)c1c(O)c2c...
# 113                       CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# 114                      O=C(Oc1ccccc1C(=O)O)c1ccccc1O
# 115                             Oc1c(I)cc(Cl)c2cccnc12
# 116   Cn1cc(-c2ccncc2)c(-c2ccc(OCc3ccc4ccccc4n3)cc2)n1
#
#                              Standardized_InChI_chembl  \
# 0    InChI=1S/C22H28N4O5/c1-30-17-7-5-15(6-8-17)25-...
# 1    InChI=1S/C22H26FN3O4/c23-18-7-2-1-6-17(18)22(2...
# 2    InChI=1S/C26H33N3O5S/c1-18(2)6-7-21-8-9-25-23(...
# 3    InChI=1S/C13H8N2O3/c16-15(17)10-6-7-12-11(8-10...
# 4    InChI=1S/C23H33FN6O4/c1-16-11-30(17(2)14-31)22...
# ..                                                 ...
# 112  InChI=1S/C19H15NO6/c1-11(21)10-15(12-6-8-13(9-...
# 113  InChI=1S/C12H15ClO3/c1-4-15-11(14)12(2,3)16-10...
# 114  InChI=1S/C14H10O5/c15-11-7-3-1-5-9(11)14(18)19...
# 115  InChI=1S/C9H5ClINO/c10-6-4-7(11)9(13)8-5(6)2-1...
# 116  InChI=1S/C25H20N4O/c1-29-16-23(18-12-14-26-15-...
#
#     Standardized_InChIKey_chembl
# 0    GEVYJHFWGQLEQA-SLFFLAALSA-N
# 1    CUFNDCCMTGJSBI-DBVUQKKJSA-N
# 2    YTUJKVHLLCOJEP-JXALWOEJSA-N
# 3    PBRISAFILDFQFS-UHFFFAOYSA-N
# 4    VTXUSJLMEZRIOV-XGHQBKJUSA-N
# ..                           ...
# 112  VABCILAOYCMVPS-HNNXBMFYSA-N
# 113  KNHUKKLJHYUCFP-UHFFFAOYSA-N
# 114  WVYADZUPLLSGPU-UHFFFAOYSA-N
# 115  QCDFBFJGMNKBDO-UHFFFAOYSA-N
# 116  AZEXWHKOMMASPA-UHFFFAOYSA-N
#
# [117 rows x 4 columns]

# %%
from chembl_webresource_client.new_client import new_client

# Set up the ChEMBL client
chembl_client = new_client

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True, nb_workers=80)
# Out:
# INFO: Pandarallel will run on 80 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
def smiles_to_chembl_id(smiles):
    try:
        molecule = chembl_client.molecule
        result = molecule.filter(smiles=smiles).only("molecule_chembl_id")
        return result[0]["molecule_chembl_id"] if result else None
    except Exception as e:
        print(f"Error converting SMILES to ChEMBL ID for {smiles}: {e}")
        return "Cannot_do"

# %%
def inchikey_to_chembl_id(inchikey):
    result = None
    
    try:
        molecule = chembl_client.molecule
        result = molecule.filter(molecule_structures__standard_inchi_key=inchikey).only("molecule_chembl_id")
        return result[0]["molecule_chembl_id"] if result else None
    except Exception as e:
        print(f"Error converting InChI key to ChEMBL ID for {inchikey}: {e}")
        return "Cannot_do"

# %%
# Apply the function to each row and create a new 'ChEMBL_ID' column
df['ChEMBL_ID'] = df['Standardized_InChIKey_chembl'].parallel_apply(inchikey_to_chembl_id)
df
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=2), Label(value='0 / 2'))), HBox(c…
#                                                 Smiles  \
# 0    COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 1    OC[C@@H]1O[C@H](CCNC(=O)Cc2ccccn2)CC[C@H]1NC(=...
# 2    CC(C)C#Cc1ccc2c(O[C@H](CN(C)C(=O)c3ccncc3)[C@H...
# 3                 [O-][N+](=O)c1ccc2oc(nc2c1)-c1ccccc1
# 4    C[C@@H](CO)N1C[C@H](C)[C@@H](CN(C)C(=O)Nc2cccc...
# ..                                                 ...
# 112  CC(=O)C[C@@H](c1ccc(cc1)[N+]([O-])=O)c1c(O)c2c...
# 113                       CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# 114                      OC(=O)c1ccccc1OC(=O)c1ccccc1O
# 115                             Oc1c(I)cc(Cl)c2cccnc12
# 116   Cn1cc(c(n1)-c1ccc(OCc2ccc3ccccc3n2)cc1)-c1ccncc1
#
#                             Standardized_SMILES_chembl  \
# 0    COc1ccc(NC(=O)N[C@H]2CC[C@@H](CC(=O)NCc3ccccn3...
# 1    O=C(Cc1ccccn1)NCC[C@@H]1CC[C@@H](NC(=O)c2ccccc...
# 2    CC(C)C#Cc1ccc2c(c1)O[C@H](CN(C)C(=O)c1ccncc1)[...
# 3                 O=[N+]([O-])c1ccc2oc(-c3ccccc3)nc2c1
# 4    C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# ..                                                 ...
# 112  CC(=O)C[C@@H](c1ccc([N+](=O)[O-])cc1)c1c(O)c2c...
# 113                       CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# 114                      O=C(Oc1ccccc1C(=O)O)c1ccccc1O
# 115                             Oc1c(I)cc(Cl)c2cccnc12
# 116   Cn1cc(-c2ccncc2)c(-c2ccc(OCc3ccc4ccccc4n3)cc2)n1
#
#                              Standardized_InChI_chembl  \
# 0    InChI=1S/C22H28N4O5/c1-30-17-7-5-15(6-8-17)25-...
# 1    InChI=1S/C22H26FN3O4/c23-18-7-2-1-6-17(18)22(2...
# 2    InChI=1S/C26H33N3O5S/c1-18(2)6-7-21-8-9-25-23(...
# 3    InChI=1S/C13H8N2O3/c16-15(17)10-6-7-12-11(8-10...
# 4    InChI=1S/C23H33FN6O4/c1-16-11-30(17(2)14-31)22...
# ..                                                 ...
# 112  InChI=1S/C19H15NO6/c1-11(21)10-15(12-6-8-13(9-...
# 113  InChI=1S/C12H15ClO3/c1-4-15-11(14)12(2,3)16-10...
# 114  InChI=1S/C14H10O5/c15-11-7-3-1-5-9(11)14(18)19...
# 115  InChI=1S/C9H5ClINO/c10-6-4-7(11)9(13)8-5(6)2-1...
# 116  InChI=1S/C25H20N4O/c1-29-16-23(18-12-14-26-15-...
#
#     Standardized_InChIKey_chembl      ChEMBL_ID
# 0    GEVYJHFWGQLEQA-SLFFLAALSA-N           None
# 1    CUFNDCCMTGJSBI-DBVUQKKJSA-N           None
# 2    YTUJKVHLLCOJEP-JXALWOEJSA-N           None
# 3    PBRISAFILDFQFS-UHFFFAOYSA-N   CHEMBL391351
# 4    VTXUSJLMEZRIOV-XGHQBKJUSA-N  CHEMBL2131431
# ..                           ...            ...
# 112  VABCILAOYCMVPS-HNNXBMFYSA-N           None
# 113  KNHUKKLJHYUCFP-UHFFFAOYSA-N      CHEMBL565
# 114  WVYADZUPLLSGPU-UHFFFAOYSA-N   CHEMBL154111
# 115  QCDFBFJGMNKBDO-UHFFFAOYSA-N      CHEMBL497
# 116  AZEXWHKOMMASPA-UHFFFAOYSA-N   CHEMBL562318
#
# [117 rows x 5 columns]

# %%
df.ChEMBL_ID.nunique()
# Out:
# 53

# %%
df.to_csv("mitotox_chemblidentifiers.csv.gz", index=False, compression="gzip")
