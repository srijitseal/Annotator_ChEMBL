# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# Set up the ChEMBL client
chembl_client = new_client

# %%
def smiles_to_chembl_id(smiles):
    try:
        molecule = chembl_client.molecule
        result = molecule.filter(smiles=smiles).only("chembl_id")
        return result[0]["chembl_id"] if result else None
    except Exception as e:
        print(f"Error converting SMILES to ChEMBL ID for {smiles}: {e}")
        return None

# %%
def get_bioactivities_for_chembl_id(chembl_id):
    try:
        # Verify the molecule exists with the given ChEMBL ID
        molecule = chembl_client.molecule
        compound_info_list = list(molecule.filter(molecule_chembl_id=chembl_id).only("molecule_chembl_id"))
        
        if not compound_info_list:
            print(f"ChEMBL ID {chembl_id} not found in the database.")
            return None

        # Fetch bioactivity data associated with the molecule
        desired_types = ["IC50", "EC50", "AC50", "GI50", "Ki"]
        bioactivities = chembl_client.activity.filter(
            molecule_chembl_id=chembl_id,
            target_type="SINGLE PROTEIN", 
            target_organism = "Homo sapiens",
            type__in=desired_types
        )

        bioactivities_list = list(bioactivities)
        
        # Fetch gene names for the targets and augment the bioactivity records
        for activity in bioactivities_list:
            
            target_id = activity["target_chembl_id"]
            target_data = chembl_client.target.filter(target_chembl_id=target_id).only("target_components")
            
            if target_data and target_data[0].get("target_components"):
                # Assuming the first component is the primary gene; modify as needed
                gene_symbol = next((synonym['component_synonym'] 
                   for synonym in target_data[0]['target_components'][0]['target_component_synonyms'] 
                   if synonym['syn_type'] == 'GENE_SYMBOL'), None)
                
                activity["gene_symbol"] = gene_symbol
            else:
                activity["gene_symbol"] = None
        return bioactivities_list
        
    except Exception as e:
        print(f"Error retrieving targets for ChEMBL ID {chembl_id}: {e}")
        return None

# %%
jumpcp = pd.read_csv("mitotox_chemblidentifiers.csv.gz", compression="gzip")
jumpcp = jumpcp[jumpcp.ChEMBL_ID.notna()].reset_index(drop=True)
jumpcp
# Out:
#                                                Smiles  \
# 0                [O-][N+](=O)c1ccc2oc(nc2c1)-c1ccccc1
# 1   C[C@@H](CO)N1C[C@H](C)[C@@H](CN(C)C(=O)Nc2cccc...
# 2                          CCSc1nn2c(nc3ccccc3c2=O)s1
# 3                   Oc1ccc(C(=O)Cc2c(F)cccc2Cl)c(O)c1
# 4                        CCc1ccc(\C=C(\C#N)C(N)=S)cc1
# 5                       Clc1ccc(NC(=S)NCCc2ccccc2)cc1
# 6   Cc1cc(C)n(CC(O)CN(c2ccc(C)cc2)S(=O)(=O)c2ccc3c...
# 7                  O=C(N1C(=O)c2cccc3cccc1c23)c1ccco1
# 8                    Brc1ccc(CSc2ccc(nn2)-c2ccco2)cc1
# 9   CCCNC(=O)C[C@@H]1CC[C@H]2[C@H](COc3ccc(NC(=O)c...
# 10             CCC(=O)c1cn(CC(=O)Nc2ccccc2F)c2ccccc12
# 11           Cc1cc(Br)ccc1NC(=O)CCN1C(=O)c2ccncc2C1=O
# 12  C[C@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2cccnc...
# 13               Clc1ccc(C(=O)NNC(=N)Cn2cncn2)c(Cl)c1
# 14                    CCCCCC(=O)NNC1=NCC(Cc2ccccc2)S1
# 15                    N#CC(C#N)=NNc1ccc(OC(F)(F)F)cc1
# 16     CN(C)S(=O)(=O)N1CCN(c2ccc([N+](=O)[O-
# 44  MQMKRQLTIWPEDM-UHFFFAOYSA-N  CHEMBL3218575
# 45  XUFXOAAUWZOOIT-SXARVLRPSA-N     CHEMBL1566
# 46  GSNOZLZNQMLSKJ-UHFFFAOYSA-N   CHEMBL132767
# 47  RFHAOTPXVQNOHP-UHFFFAOYSA-N      CHEMBL106
# 48  NPUKDXXFDDZOKR-LLVKDONJSA-N      CHEMBL681
# 49  KNHUKKLJHYUCFP-UHFFFAOYSA-N      CHEMBL565
# 50  WVYADZUPLLSGPU-UHFFFAOYSA-N   CHEMBL154111
# 51  QCDFBFJGMNKBDO-UHFFFAOYSA-N      CHEMBL497
# 52  AZEXWHKOMMASPA-UHFFFAOYSA-N   CHEMBL562318

# %%
jumpcp.ChEMBL_ID.unique()[:10]
# Out:
# array(['CHEMBL391351', 'CHEMBL2131431', 'CHEMBL1469668', 'CHEMBL1563942',
#        'CHEMBL1382221', 'CHEMBL1548970', 'CHEMBL1366886', 'CHEMBL1524294',
#        'CHEMBL1572364', 'CHEMBL2356652'], dtype=object)

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True, nb_workers=80)

# List of ChEMBL IDs
chembl_ids = jumpcp.ChEMBL_ID.unique()[:]


# Use parallel_apply to retrieve data for each ChEMBL ID in parallel
dfs = pd.Series(chembl_ids).parallel_apply(get_bioactivities_for_chembl_id)
# Out:
# INFO: Pandarallel will run on 80 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1), Label(value='0 / 1'))), HBox(c…

# %%
# Convert each list of dictionaries in dfs to a DataFrame
dfs_list = [pd.DataFrame(data_dict) for data_dict in dfs]

# Concatenate all the DataFrames
final_df = pd.concat(dfs_list, ignore_index=True)
final_df
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0           None             None     12610128                  []
# 1           None             None     12610144                  []
# 2           None             None     12610160                  []
# 3           None             None      5123272                  []
# 4           None             None      5123273                  []
# ...          ...              ...          ...                 ...
# 3931        None             None     14650842                  []
# 3932        None             None     15151305                  []
# 3933        None             None     15652501                  []
# 3934        None           328085     17706675                  []
# 3935        None             None     19052129                  []
#
#      assay_chembl_id                                  assay_description  \
# 0      CHEMBL3069189  Cytotoxicity against Homo sapiens (human) MOLT...
# 1      CHEMBL3069190  Cytotoxicity against Homo sapiens (human) HepG...
# 2      CHEMBL3069191  Cytotoxicity against Homo sapiens (human) A549...
# 3      CHEMBL1647397  Inhibition of hypoxia-induced HIF1 activation ...
# 4      CHEMBL1647398  Inhibition of 1, 10-phenanthroline-induced HIF...
# ...              ...                                                ...
# 3931   CHEMBL3268063  Inhibition of N-terminal GST-tagged human reco...
# 3932   CHEMBL3395317        Binding affinity to PDE10A (unknown origin)
# 3933   CHEMBL3595648              Inhibition of PDE10A (unknown origin)
# 3934   CHEMBL3887283  HTRF Assay: The PDE enzymatic reaction was car...
# 3935   CHEMBL4355198  Inhibition of human PDE10A2 catalytic domain (...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             F                    None                   None  BAO_0000190
# 1             F                    None                   None  BAO_0000190
# 2             F                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 3931          B                    None                   None  BAO_0000190
# 3932          B                    None                   None  BAO_0000190
# 3933          B                    None                   None  BAO_0000190
# 3934          B                    None                   None  BAO_0000190
# 3935          B                    None                   None  BAO_0000190
#
#       ...                                   target_pref_name target_tax_id  \
# 0     ...                                             MOLT-3          9606
# 1     ...                                              HepG2          9606
# 2     ...                                               A549          9606
# 3     ...  Hypoxia inducible factors; HIF-1-alpha, HIF-2-...          9606
# 4     ...  Hypoxia inducible factors; HIF-1-alpha, HIF-2-...          9606
# ...   ...                                                ...           ...
# 3931  ...                              Phosphodiesterase 10A          9606
# 3932  ...                              Phosphodiesterase 10A          9606
# 3933  ...                              Phosphodiesterase 10A          9606
# 3934  ...                              Phosphodiesterase 10A          9606
# 3935  ...                              Phosphodiesterase 10A          9606
#
#      text_value  toid  type units    uo_units  upper_value  value gene_symbol
# 0          None  None  IC50    uM  UO_0000065         None  25.14        None
# 1          None  None  IC50    uM  UO_0000065         None   44.7        None
# 2          None  None  IC50    uM  UO_0000065         None  75.65        None
# 3          None  None  IC50    uM  UO_0000065         None   0.51       HIF1A
# 4          None  None  IC50    uM  UO_0000065         None   0.31       HIF1A
# ...         ...   ...   ...   ...         ...          ...    ...         ...
# 3931       None  None  IC50    nM  UO_0000065         None   0.37      PDE10A
# 3932       None  None  IC50    nM  UO_0000065         None   0.18      PDE10A
# 3933       None  None  IC50    nM  UO_0000065         None    2.6      PDE10A
# 3934       None  None  IC50    nM  UO_0000065         None   1.68      PDE10A
# 3935       None  None  IC50    nM  UO_0000065         None   0.37      PDE10A
#
# [3936 rows x 47 columns]

# %%
final_df = final_df[final_df.gene_symbol.notna()]
mask = ~final_df['assay_description'].str.lower().str.contains('mutant|recombinant')
final_df = final_df[mask].sort_values("type").reset_index(drop=True)
final_df
# Out:
#      action_type                                   activity_comment  \
# 0           None  Summarised AC50 (mean value for measurements w...
# 1           None  Summarised AC50 (mean value for measurements w...
# 2           None  Summarised AC50 (mean value for measurements w...
# 3           None  Summarised AC50 (mean value for measurements w...
# 4           None  Summarised AC50 (mean value for measurements w...
# ...          ...                                                ...
# 3574        None  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575        None  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576        None  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577        None  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578        None  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 0        25176239                  []   CHEMBL5291850
# 1        25225574                  []   CHEMBL5291817
# 2        25224563                  []   CHEMBL5291844
# 3        25223994                  []   CHEMBL5291845
# 4        25223385                  []   CHEMBL5291860
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 0     Binding affinity towards human NR3C1 in an in ...          B
# 1     Antagonist activity at human HTR2A in an in vi...          F
# 2     Agonist activity at human NR1I2 in an in vitro...          F
# 3     Antagonist activity at human NR1I2 in an in vi...          F
# 4     Agonist activity at human PGR in an in vitro c...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000186  ...
# 1                       None                   None  BAO_0000186  ...
# 2                       None                   None  BAO_0000186  ...
# 3                       None                   None  BAO_0000186  ...
# 4                       None                   None  BAO_0000186  ...
# ...                      ...                    ...          ...  ...
# 3574                    None                   None  BAO_0000192  ...
# 3575                    None                   None  BAO_0000192  ...
# 3576                    None                   None  BAO_0000192  ...
# 3577                    None                   None  BAO_0000192  ...
# 3578                    None                   None  BAO_0000192  ...
#
#                     target_pref_name target_tax_id text_value  toid  type  \
# 0            Glucocorticoid receptor          9606       None  None  AC50
# 1     Serotonin 2a (5-HT2a) receptor          9606       None  None  AC50
# 2                Pregnane X receptor          9606       None  None  AC50
# 3                Pregnane X receptor          9606       None  None  AC50
# 4              Progesterone receptor          9606       None  None  AC50
# ...                              ...           ...        ...   ...   ...
# 3574      Norepinephrine transporter          9606       None  None    Ki
# 3575            Cytochrome P450 2C19          9606       None  None    Ki
# 3576             Cytochrome P450 2A6          9606       None  None    Ki
# 3577        Endothelin receptor ET-A          9606       None  None    Ki
# 3578    Alpha-2c adrenergic receptor          9606       None  None    Ki
#
#      units    uo_units  upper_value value gene_symbol
# 0       uM  UO_0000065         None  30.0       NR3C1
# 1       uM  UO_0000065         None  10.0       HTR2A
# 2       uM  UO_0000065         None  30.0       NR1I2
# 3       uM  UO_0000065         None  30.0       NR1I2
# 4       uM  UO_0000065         None  30.0         PGR
# ...    ...         ...          ...   ...         ...
# 3574  None        None         None  None      SLC6A2
# 3575  None        None         None  None     CYP2C19
# 3576  None        None         None  None      CYP2A6
# 3577  None        None         None  None       EDNRA
# 3578  None        None         None  None      ADRA2C
#
# [3579 rows x 47 columns]

# %%
final_df.parent_molecule_chembl_id.unique()
# Out:
# array(['CHEMBL1324', 'CHEMBL1622', 'CHEMBL139', 'CHEMBL1201256',
#        'CHEMBL106', 'CHEMBL681', 'CHEMBL515', 'CHEMBL1566', 'CHEMBL113',
#        'CHEMBL279678', 'CHEMBL256997', 'CHEMBL132767', 'CHEMBL1043',
#        'CHEMBL109', 'CHEMBL1289494', 'CHEMBL565', 'CHEMBL1111',
#        'CHEMBL497', 'CHEMBL154111', 'CHEMBL959', 'CHEMBL549', 'CHEMBL658',
#        'CHEMBL1095777', 'CHEMBL3218575', 'CHEMBL457504', 'CHEMBL562318',
#        'CHEMBL2143592', 'CHEMBL1518572', 'CHEMBL22373', 'CHEMBL47302'],
#       dtype=object)

# %%
final_df.to_csv("Binding_activities_chembl_mitotox.csv.gz", index=False, compression='gzip')

# %%
import pandas as pd

# %%
final_df = pd.read_csv("Binding_activities_chembl_mitotox.csv.gz", compression='gzip', low_memory=False)
final_df
# Out:
#      action_type                                   activity_comment  \
# 0            NaN  Summarised AC50 (mean value for measurements w...
# 1            NaN  Summarised AC50 (mean value for measurements w...
# 2            NaN  Summarised AC50 (mean value for measurements w...
# 3            NaN  Summarised AC50 (mean value for measurements w...
# 4            NaN  Summarised AC50 (mean value for measurements w...
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 0        25176239                  []   CHEMBL5291850
# 1        25225574                  []   CHEMBL5291817
# 2        25224563                  []   CHEMBL5291844
# 3        25223994                  []   CHEMBL5291845
# 4        25223385                  []   CHEMBL5291860
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 0     Binding affinity towards human NR3C1 in an in ...          B
# 1     Antagonist activity at human HTR2A in an in vi...          F
# 2     Agonist activity at human NR1I2 in an in vitro...          F
# 3     Antagonist activity at human NR1I2 in an in vi...          F
# 4     Agonist activity at human PGR in an in vitro c...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 0                         NaN                     NaN  BAO_0000186  ...
# 1                         NaN                     NaN  BAO_0000186  ...
# 2                         NaN                     NaN  BAO_0000186  ...
# 3                         NaN                     NaN  BAO_0000186  ...
# 4                         NaN                     NaN  BAO_0000186  ...
# ...                       ...                     ...          ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...
# 3575                      NaN                     NaN  BAO_0000192  ...
# 3576                      NaN                     NaN  BAO_0000192  ...
# 3577                      NaN                     NaN  BAO_0000192  ...
# 3578                      NaN                     NaN  BAO_0000192  ...
#
#                     target_pref_name target_tax_id text_value toid  type  \
# 0            Glucocorticoid receptor          9606        NaN  NaN  AC50
# 1     Serotonin 2a (5-HT2a) receptor          9606        NaN  NaN  AC50
# 2                Pregnane X receptor          9606        NaN  NaN  AC50
# 3                Pregnane X receptor          9606        NaN  NaN  AC50
# 4              Progesterone receptor          9606        NaN  NaN  AC50
# ...                              ...           ...        ...  ...   ...
# 3574      Norepinephrine transporter          9606        NaN  NaN    Ki
# 3575            Cytochrome P450 2C19          9606        NaN  NaN    Ki
# 3576             Cytochrome P450 2A6          9606        NaN  NaN    Ki
# 3577        Endothelin receptor ET-A          9606        NaN  NaN    Ki
# 3578    Alpha-2c adrenergic receptor          9606        NaN  NaN    Ki
#
#      units    uo_units  upper_value value gene_symbol
# 0       uM  UO_0000065          NaN  30.0       NR3C1
# 1       uM  UO_0000065          NaN  10.0       HTR2A
# 2       uM  UO_0000065          NaN  30.0       NR1I2
# 3       uM  UO_0000065          NaN  30.0       NR1I2
# 4       uM  UO_0000065          NaN  30.0         PGR
# ...    ...         ...          ...   ...         ...
# 3574   NaN         NaN          NaN   NaN      SLC6A2
# 3575   NaN         NaN          NaN   NaN     CYP2C19
# 3576   NaN         NaN          NaN   NaN      CYP2A6
# 3577   NaN         NaN          NaN   NaN       EDNRA
# 3578   NaN         NaN          NaN   NaN      ADRA2C
#
# [3579 rows x 47 columns]

# %%
final_df.standard_relation.unique()
# Out:
# array(['>', '=', nan, '<', '~'], dtype=object)

# %%
final_df = final_df[~final_df["standard_relation"].isin(['>', '<', '~', '>=', '<=', '>>'])]
final_df
# Out:
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 5                         NaN                     NaN  BAO_0000186  ...
# 9                         NaN                     NaN  BAO_0000186  ...
# 15                        NaN                     NaN  BAO_0000186  ...
# 30                        NaN                     NaN  BAO_0000186  ...
# 31                        NaN                     NaN  BAO_0000186  ...
# ...                       ...                     ...          ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...
# 3575                      NaN                     NaN  BAO_0000192  ...
# 3576                      NaN                     NaN  BAO_0000192  ...
# 3577                      NaN                     NaN  BAO_0000192  ...
# 3578                      NaN                     NaN  BAO_0000192  ...
#
#                     target_pref_name target_tax_id text_value toid  type  \
# 5              Progesterone receptor          9606        NaN  NaN  AC50
# 9     Serotonin 1a (5-HT1a) receptor          9606        NaN  NaN  AC50
# 15       Retinoic acid receptor beta          9606        NaN  NaN  AC50
# 30               Cytochrome P450 1A2          9606        NaN  NaN  AC50
# 31              Cytochrome P450 2C19          9606        NaN  NaN  AC50
# ...                              ...           ...        ...  ...   ...
# 3574      Norepinephrine transporter          9606        NaN  NaN    Ki
# 3575            Cytochrome P450 2C19          9606        NaN  NaN    Ki
# 3576             Cytochrome P450 2A6          9606        NaN  NaN    Ki
# 3577        Endothelin receptor ET-A          9606        NaN  NaN    Ki
# 3578    Alpha-2c adrenergic receptor          9606        NaN  NaN    Ki
#
#      units    uo_units  upper_value    value gene_symbol
# 5       uM  UO_0000065          NaN   1.0915         PGR
# 9       uM  UO_0000065          NaN   5.6000       HTR1A
# 15      uM  UO_0000065          NaN  25.9998        RARB
# 30     NaN         NaN          NaN      NaN      CYP1A2
# 31     NaN         NaN          NaN      NaN     CYP2C19
# ...    ...         ...          ...      ...         ...
# 3574   NaN         NaN          NaN      NaN      SLC6A2
# 3575   NaN         NaN          NaN      NaN     CYP2C19
# 3576   NaN         NaN          NaN      NaN      CYP2A6
# 3577   NaN         NaN          NaN      NaN       EDNRA
# 3578   NaN         NaN          NaN      NaN      ADRA2C
#
# [2181 rows x 47 columns]

# %%
final_df = final_df[final_df["activity_comment"].str.lower()!="inconclusive"]
final_df
# Out:
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 5                         NaN                     NaN  BAO_0000186  ...
# 9                         NaN                     NaN  BAO_0000186  ...
# 15                        NaN                     NaN  BAO_0000186  ...
# 30                        NaN                     NaN  BAO_0000186  ...
# 31                        NaN                     NaN  BAO_0000186  ...
# ...                       ...                     ...          ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...
# 3575                      NaN                     NaN  BAO_0000192  ...
# 3576                      NaN                     NaN  BAO_0000192  ...
# 3577                      NaN                     NaN  BAO_0000192  ...
# 3578                      NaN                     NaN  BAO_0000192  ...
#
#                     target_pref_name target_tax_id text_value toid  type  \
# 5              Progesterone receptor          9606        NaN  NaN  AC50
# 9     Serotonin 1a (5-HT1a) receptor          9606        NaN  NaN  AC50
# 15       Retinoic acid receptor beta          9606        NaN  NaN  AC50
# 30               Cytochrome P450 1A2          9606        NaN  NaN  AC50
# 31              Cytochrome P450 2C19          9606        NaN  NaN  AC50
# ...                              ...           ...        ...  ...   ...
# 3574      Norepinephrine transporter          9606        NaN  NaN    Ki
# 3575            Cytochrome P450 2C19          9606        NaN  NaN    Ki
# 3576             Cytochrome P450 2A6          9606        NaN  NaN    Ki
# 3577        Endothelin receptor ET-A          9606        NaN  NaN    Ki
# 3578    Alpha-2c adrenergic receptor          9606        NaN  NaN    Ki
#
#      units    uo_units  upper_value    value gene_symbol
# 5       uM  UO_0000065          NaN   1.0915         PGR
# 9       uM  UO_0000065          NaN   5.6000       HTR1A
# 15      uM  UO_0000065          NaN  25.9998        RARB
# 30     NaN         NaN          NaN      NaN      CYP1A2
# 31     NaN         NaN          NaN      NaN     CYP2C19
# ...    ...         ...          ...      ...         ...
# 3574   NaN         NaN          NaN      NaN      SLC6A2
# 3575   NaN         NaN          NaN      NaN     CYP2C19
# 3576   NaN         NaN          NaN      NaN      CYP2A6
# 3577   NaN         NaN          NaN      NaN       EDNRA
# 3578   NaN         NaN          NaN      NaN      ADRA2C
#
# [2176 rows x 47 columns]

# %%
final_df = final_df[~final_df.standard_units.isin(['mg kg-1', 'ug.mL-1', 'uM tube-1', "10'3pM",
       '10^2 uM', 's-1', '10^-2/min', "10'5/M/min", 'Ratio', '10^-9/min',
       'ug ml-1', 'nM l-1 hr-1'])]
final_df
# Out:
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 5                         NaN                     NaN  BAO_0000186  ...
# 9                         NaN                     NaN  BAO_0000186  ...
# 15                        NaN                     NaN  BAO_0000186  ...
# 30                        NaN                     NaN  BAO_0000186  ...
# 31                        NaN                     NaN  BAO_0000186  ...
# ...                       ...                     ...          ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...
# 3575                      NaN                     NaN  BAO_0000192  ...
# 3576                      NaN                     NaN  BAO_0000192  ...
# 3577                      NaN                     NaN  BAO_0000192  ...
# 3578                      NaN                     NaN  BAO_0000192  ...
#
#                     target_pref_name target_tax_id text_value toid  type  \
# 5              Progesterone receptor          9606        NaN  NaN  AC50
# 9     Serotonin 1a (5-HT1a) receptor          9606        NaN  NaN  AC50
# 15       Retinoic acid receptor beta          9606        NaN  NaN  AC50
# 30               Cytochrome P450 1A2          9606        NaN  NaN  AC50
# 31              Cytochrome P450 2C19          9606        NaN  NaN  AC50
# ...                              ...           ...        ...  ...   ...
# 3574      Norepinephrine transporter          9606        NaN  NaN    Ki
# 3575            Cytochrome P450 2C19          9606        NaN  NaN    Ki
# 3576             Cytochrome P450 2A6          9606        NaN  NaN    Ki
# 3577        Endothelin receptor ET-A          9606        NaN  NaN    Ki
# 3578    Alpha-2c adrenergic receptor          9606        NaN  NaN    Ki
#
#      units    uo_units  upper_value    value gene_symbol
# 5       uM  UO_0000065          NaN   1.0915         PGR
# 9       uM  UO_0000065          NaN   5.6000       HTR1A
# 15      uM  UO_0000065          NaN  25.9998        RARB
# 30     NaN         NaN          NaN      NaN      CYP1A2
# 31     NaN         NaN          NaN      NaN     CYP2C19
# ...    ...         ...          ...      ...         ...
# 3574   NaN         NaN          NaN      NaN      SLC6A2
# 3575   NaN         NaN          NaN      NaN     CYP2C19
# 3576   NaN         NaN          NaN      NaN      CYP2A6
# 3577   NaN         NaN          NaN      NaN       EDNRA
# 3578   NaN         NaN          NaN      NaN      ADRA2C
#
# [2172 rows x 47 columns]

# %%
import pandas as pd
import ast

# Convert the string representation of dictionary to an actual dictionary (if required)
final_df['action_type'] = final_df['action_type'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
final_df
# Out:
# /tmp/ipykernel_61979/2256060974.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['action_type'] = final_df['action_type'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 5                         NaN                     NaN  BAO_0000186  ...
# 9                         NaN                     NaN  BAO_0000186  ...
# 15                        NaN                     NaN  BAO_0000186  ...
# 30                        NaN                     NaN  BAO_0000186  ...
# 31                        NaN                     NaN  BAO_0000186  ...
# ...                       ...                     ...          ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...
# 3575                      NaN                     NaN  BAO_0000192  ...
# 3576                      NaN                     NaN  BAO_0000192  ...
# 3577                      NaN                     NaN  BAO_0000192  ...
# 3578                      NaN                     NaN  BAO_0000192  ...
#
#                     target_pref_name target_tax_id text_value toid  type  \
# 5              Progesterone receptor          9606        NaN  NaN  AC50
# 9     Serotonin 1a (5-HT1a) receptor          9606        NaN  NaN  AC50
# 15       Retinoic acid receptor beta          9606        NaN  NaN  AC50
# 30               Cytochrome P450 1A2          9606        NaN  NaN  AC50
# 31              Cytochrome P450 2C19          9606        NaN  NaN  AC50
# ...                              ...           ...        ...  ...   ...
# 3574      Norepinephrine transporter          9606        NaN  NaN    Ki
# 3575            Cytochrome P450 2C19          9606        NaN  NaN    Ki
# 3576             Cytochrome P450 2A6          9606        NaN  NaN    Ki
# 3577        Endothelin receptor ET-A          9606        NaN  NaN    Ki
# 3578    Alpha-2c adrenergic receptor          9606        NaN  NaN    Ki
#
#      units    uo_units  upper_value    value gene_symbol
# 5       uM  UO_0000065          NaN   1.0915         PGR
# 9       uM  UO_0000065          NaN   5.6000       HTR1A
# 15      uM  UO_0000065          NaN  25.9998        RARB
# 30     NaN         NaN          NaN      NaN      CYP1A2
# 31     NaN         NaN          NaN      NaN     CYP2C19
# ...    ...         ...          ...      ...         ...
# 3574   NaN         NaN          NaN      NaN      SLC6A2
# 3575   NaN         NaN          NaN      NaN     CYP2C19
# 3576   NaN         NaN          NaN      NaN      CYP2A6
# 3577   NaN         NaN          NaN      NaN       EDNRA
# 3578   NaN         NaN          NaN      NaN      ADRA2C
#
# [2172 rows x 47 columns]

# %%
# Extract dictionary values to separate columns
expanded_data = final_df['action_type'].apply(pd.Series)
expanded_data
# Out:
#        0 action_type description parent_type
# 5    NaN         NaN         NaN         NaN
# 9    NaN         NaN         NaN         NaN
# 15   NaN         NaN         NaN         NaN
# 30   NaN         NaN         NaN         NaN
# 31   NaN         NaN         NaN         NaN
# ...   ..         ...         ...         ...
# 3574 NaN         NaN         NaN         NaN
# 3575 NaN         NaN         NaN         NaN
# 3576 NaN         NaN         NaN         NaN
# 3577 NaN         NaN         NaN         NaN
# 3578 NaN         NaN         NaN         NaN
#
# [2172 rows x 4 columns]

# %%
final_df["action_type"] = expanded_data["action_type"] 
final_df["description"] = expanded_data["description"] 
final_df["parent_type"] = expanded_data["parent_type"] 
final_df
# Out:
# /tmp/ipykernel_61979/3071467124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["action_type"] = expanded_data["action_type"]
# /tmp/ipykernel_61979/3071467124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["description"] = expanded_data["description"]
# /tmp/ipykernel_61979/3071467124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["parent_type"] = expanded_data["parent_type"]
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 5                         NaN                     NaN  BAO_0000186  ...
# 9                         NaN                     NaN  BAO_0000186  ...
# 15                        NaN                     NaN  BAO_0000186  ...
# 30                        NaN                     NaN  BAO_0000186  ...
# 31                        NaN                     NaN  BAO_0000186  ...
# ...                       ...                     ...          ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...
# 3575                      NaN                     NaN  BAO_0000192  ...
# 3576                      NaN                     NaN  BAO_0000192  ...
# 3577                      NaN                     NaN  BAO_0000192  ...
# 3578                      NaN                     NaN  BAO_0000192  ...
#
#      text_value toid  type units    uo_units upper_value    value  \
# 5           NaN  NaN  AC50    uM  UO_0000065         NaN   1.0915
# 9           NaN  NaN  AC50    uM  UO_0000065         NaN   5.6000
# 15          NaN  NaN  AC50    uM  UO_0000065         NaN  25.9998
# 30          NaN  NaN  AC50   NaN         NaN         NaN      NaN
# 31          NaN  NaN  AC50   NaN         NaN         NaN      NaN
# ...         ...  ...   ...   ...         ...         ...      ...
# 3574        NaN  NaN    Ki   NaN         NaN         NaN      NaN
# 3575        NaN  NaN    Ki   NaN         NaN         NaN      NaN
# 3576        NaN  NaN    Ki   NaN         NaN         NaN      NaN
# 3577        NaN  NaN    Ki   NaN         NaN         NaN      NaN
# 3578        NaN  NaN    Ki   NaN         NaN         NaN      NaN
#
#       gene_symbol description parent_type
# 5             PGR         NaN         NaN
# 9           HTR1A         NaN         NaN
# 15           RARB         NaN         NaN
# 30         CYP1A2         NaN         NaN
# 31        CYP2C19         NaN         NaN
# ...           ...         ...         ...
# 3574       SLC6A2         NaN         NaN
# 3575      CYP2C19         NaN         NaN
# 3576       CYP2A6         NaN         NaN
# 3577        EDNRA         NaN         NaN
# 3578       ADRA2C         NaN         NaN
#
# [2172 rows x 49 columns]

# %%
def clean_activity_comment(value):
    value_str = str(value).lower()
    
    if 'inhibitor' in value_str:
        return 'inhibitor'
    elif 'inactive' in value_str or 'not active' in value_str:
        return 'inactive'
    elif 'active' in value_str:
        return 'active' 
    elif 'substrate' in value_str:
        return 'substrate'
    elif 'antagonist' in value_str:
        return 'antagonist'
    elif 'inverse agonist' in value_str:
        return 'inverse agonist'
    elif 'agonist' in value_str:
        return 'agonist'
    elif pd.isna(value) or 'nan' in value_str:
        return 'no data'
    else:
        return 'unknown'

final_df['activity_comment_class'] = final_df['activity_comment'].apply(clean_activity_comment)
final_df['action_type'] = final_df['action_type'].str.lower()
final_df
# Out:
# /tmp/ipykernel_61979/3856125844.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['activity_comment_class'] = final_df['activity_comment'].apply(clean_activity_comment)
# /tmp/ipykernel_61979/3856125844.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['action_type'] = final_df['action_type'].str.lower()
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ... toid  \
# 5                         NaN                     NaN  BAO_0000186  ...  NaN
# 9                         NaN                     NaN  BAO_0000186  ...  NaN
# 15                        NaN                     NaN  BAO_0000186  ...  NaN
# 30                        NaN                     NaN  BAO_0000186  ...  NaN
# 31                        NaN                     NaN  BAO_0000186  ...  NaN
# ...                       ...                     ...          ...  ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...  NaN
# 3575                      NaN                     NaN  BAO_0000192  ...  NaN
# 3576                      NaN                     NaN  BAO_0000192  ...  NaN
# 3577                      NaN                     NaN  BAO_0000192  ...  NaN
# 3578                      NaN                     NaN  BAO_0000192  ...  NaN
#
#       type units    uo_units upper_value    value gene_symbol  description  \
# 5     AC50    uM  UO_0000065         NaN   1.0915         PGR          NaN
# 9     AC50    uM  UO_0000065         NaN   5.6000       HTR1A          NaN
# 15    AC50    uM  UO_0000065         NaN  25.9998        RARB          NaN
# 30    AC50   NaN         NaN         NaN      NaN      CYP1A2          NaN
# 31    AC50   NaN         NaN         NaN      NaN     CYP2C19          NaN
# ...    ...   ...         ...         ...      ...         ...          ...
# 3574    Ki   NaN         NaN         NaN      NaN      SLC6A2          NaN
# 3575    Ki   NaN         NaN         NaN      NaN     CYP2C19          NaN
# 3576    Ki   NaN         NaN         NaN      NaN      CYP2A6          NaN
# 3577    Ki   NaN         NaN         NaN      NaN       EDNRA          NaN
# 3578    Ki   NaN         NaN         NaN      NaN      ADRA2C          NaN
#
#      parent_type activity_comment_class
# 5            NaN                unknown
# 9            NaN                unknown
# 15           NaN                unknown
# 30           NaN               inactive
# 31           NaN               inactive
# ...          ...                    ...
# 3574         NaN               inactive
# 3575         NaN               inactive
# 3576         NaN               inactive
# 3577         NaN               inactive
# 3578         NaN               inactive
#
# [2172 rows x 50 columns]

# %%
final_df.action_type.value_counts()
# Out:
# action_type
# inhibitor     33
# antagonist     9
# agonist        1
# stabiliser     1
# Name: count, dtype: int64

# %%
final_df.activity_comment_class.value_counts()
# Out:
# activity_comment_class
# inactive     1788
# no data       261
# unknown       110
# active         11
# inhibitor       2
# Name: count, dtype: int64

# %%
import numpy as np

# Create the mask
mask = final_df['pchembl_value'].isna() ^ final_df['value'].isna()

# Apply the computation
def calculate_pchembl(row):
    if row['standard_value'] == 0:
        return np.nan  # or some other placeholder value
    elif row['standard_units'] == 'µM':
        return -np.log10(row['standard_value'] * 10**-6)
    elif row['standard_units'] == 'nM':
        return -np.log10(row['standard_value'] * 10**-9)
    else:
        return np.nan  # Discard if %

final_df.loc[mask, 'pchembl_value'] = final_df[mask].apply(calculate_pchembl, axis=1)

final_df
# Out:
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ... toid  \
# 5                         NaN                     NaN  BAO_0000186  ...  NaN
# 9                         NaN                     NaN  BAO_0000186  ...  NaN
# 15                        NaN                     NaN  BAO_0000186  ...  NaN
# 30                        NaN                     NaN  BAO_0000186  ...  NaN
# 31                        NaN                     NaN  BAO_0000186  ...  NaN
# ...                       ...                     ...          ...  ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...  NaN
# 3575                      NaN                     NaN  BAO_0000192  ...  NaN
# 3576                      NaN                     NaN  BAO_0000192  ...  NaN
# 3577                      NaN                     NaN  BAO_0000192  ...  NaN
# 3578                      NaN                     NaN  BAO_0000192  ...  NaN
#
#       type units    uo_units upper_value    value gene_symbol  description  \
# 5     AC50    uM  UO_0000065         NaN   1.0915         PGR          NaN
# 9     AC50    uM  UO_0000065         NaN   5.6000       HTR1A          NaN
# 15    AC50    uM  UO_0000065         NaN  25.9998        RARB          NaN
# 30    AC50   NaN         NaN         NaN      NaN      CYP1A2          NaN
# 31    AC50   NaN         NaN         NaN      NaN     CYP2C19          NaN
# ...    ...   ...         ...         ...      ...         ...          ...
# 3574    Ki   NaN         NaN         NaN      NaN      SLC6A2          NaN
# 3575    Ki   NaN         NaN         NaN      NaN     CYP2C19          NaN
# 3576    Ki   NaN         NaN         NaN      NaN      CYP2A6          NaN
# 3577    Ki   NaN         NaN         NaN      NaN       EDNRA          NaN
# 3578    Ki   NaN         NaN         NaN      NaN      ADRA2C          NaN
#
#      parent_type activity_comment_class
# 5            NaN                unknown
# 9            NaN                unknown
# 15           NaN                unknown
# 30           NaN               inactive
# 31           NaN               inactive
# ...          ...                    ...
# 3574         NaN               inactive
# 3575         NaN               inactive
# 3576         NaN               inactive
# 3577         NaN               inactive
# 3578         NaN               inactive
#
# [2172 rows x 50 columns]

# %%
# Replace 'no data' values based on the condition
final_df.loc[(final_df['activity_comment_class'] == 'no data') & (final_df['pchembl_value'] > 6.5), 'activity_comment_class'] = 'active'
final_df.loc[(final_df['activity_comment_class'] == 'no data') & (final_df['pchembl_value'] <= 6.5), 'activity_comment_class'] = 'inactive'

# Replace 'unknown' values based on the condition
final_df.loc[(final_df['activity_comment_class'] == 'unknown') & (final_df['pchembl_value'] > 6.5), 'activity_comment_class'] = 'active'
final_df.loc[(final_df['activity_comment_class'] == 'unknown') & (final_df['pchembl_value'] <= 6.5), 'activity_comment_class'] = 'inactive'

final_df
# Out:
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ... toid  \
# 5                         NaN                     NaN  BAO_0000186  ...  NaN
# 9                         NaN                     NaN  BAO_0000186  ...  NaN
# 15                        NaN                     NaN  BAO_0000186  ...  NaN
# 30                        NaN                     NaN  BAO_0000186  ...  NaN
# 31                        NaN                     NaN  BAO_0000186  ...  NaN
# ...                       ...                     ...          ...  ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...  NaN
# 3575                      NaN                     NaN  BAO_0000192  ...  NaN
# 3576                      NaN                     NaN  BAO_0000192  ...  NaN
# 3577                      NaN                     NaN  BAO_0000192  ...  NaN
# 3578                      NaN                     NaN  BAO_0000192  ...  NaN
#
#       type units    uo_units upper_value    value gene_symbol  description  \
# 5     AC50    uM  UO_0000065         NaN   1.0915         PGR          NaN
# 9     AC50    uM  UO_0000065         NaN   5.6000       HTR1A          NaN
# 15    AC50    uM  UO_0000065         NaN  25.9998        RARB          NaN
# 30    AC50   NaN         NaN         NaN      NaN      CYP1A2          NaN
# 31    AC50   NaN         NaN         NaN      NaN     CYP2C19          NaN
# ...    ...   ...         ...         ...      ...         ...          ...
# 3574    Ki   NaN         NaN         NaN      NaN      SLC6A2          NaN
# 3575    Ki   NaN         NaN         NaN      NaN     CYP2C19          NaN
# 3576    Ki   NaN         NaN         NaN      NaN      CYP2A6          NaN
# 3577    Ki   NaN         NaN         NaN      NaN       EDNRA          NaN
# 3578    Ki   NaN         NaN         NaN      NaN      ADRA2C          NaN
#
#      parent_type activity_comment_class
# 5            NaN               inactive
# 9            NaN               inactive
# 15           NaN               inactive
# 30           NaN               inactive
# 31           NaN               inactive
# ...          ...                    ...
# 3574         NaN               inactive
# 3575         NaN               inactive
# 3576         NaN               inactive
# 3577         NaN               inactive
# 3578         NaN               inactive
#
# [2172 rows x 50 columns]

# %%
final_df.activity_comment_class.value_counts()
# Out:
# activity_comment_class
# inactive     2045
# active        108
# unknown        17
# inhibitor       2
# Name: count, dtype: int64

# %%
final_df.action_type.value_counts()
# Out:
# action_type
# inhibitor     33
# antagonist     9
# agonist        1
# stabiliser     1
# Name: count, dtype: int64

# %%
target_actions = ['activator', 'substrate', 'agonist', 'inhibitor',
       'antagonist', 'degrader', 'partial agonist',
       'positive allosteric modulator', 'stabiliser', 'inverse agonist',
       'modulator', 'blocker', 'negative allosteric modulator',
       'binding agent', 'disrupting agent']

# Identify rows where action_type is in target_actions and activity_comment_class is not "active"
mask = (final_df['action_type'].isin(target_actions)) & (final_df['activity_comment_class'] == 'inactive')

# Store these rows in a new dataframe for manual check
rows_to_check = final_df[mask].copy()

# Update 'activity_comment_class' in the original dataframe
final_df.loc[mask, 'activity_comment_class'] = final_df['action_type']

print("Rows to manually check:")
rows_to_check
# Out:
# Rows to manually check:
#      action_type activity_comment  activity_id  \
# 1460   inhibitor              NaN     24973113
# 1500   inhibitor              NaN     25005735
# 1501   inhibitor              NaN     25005736
# 1736   inhibitor              NaN     25094792
# 1737   inhibitor              NaN     24988979
# 1738   inhibitor              NaN     24988977
# 1739   inhibitor              NaN     23279743
# 1741   inhibitor              NaN     23147409
# 1997   inhibitor              NaN     24667652
# 2092   inhibitor              NaN     24973071
# 2093   inhibitor              NaN     24973068
# 2094   inhibitor              NaN     24973065
# 2096   inhibitor              NaN     24973062
# 2097   inhibitor              NaN     24777478
# 2111   inhibitor              NaN     24973112
# 2242   inhibitor              NaN     22967028
# 2282   inhibitor              NaN     24691609
# 2284   inhibitor              NaN     22960192
# 2287  stabiliser              NaN     23263050
# 2404   inhibitor              NaN     24667660
# 2405   inhibitor              NaN     24667659
# 2406   inhibitor              NaN     24667657
# 2407   inhibitor              NaN     24667656
# 2408   inhibitor              NaN     24667655
# 3064  antagonist              NaN     22459727
# 3066  antagonist              NaN     22459786
# 3068  antagonist              NaN     22459838
# 3071  antagonist              NaN     22756948
# 3072   inhibitor              NaN     22756952
# 3074  antagonist              NaN     24772301
# 3076  antagonist              NaN     24772305
# 3079  antagonist              NaN     22459664
# 3097  antagonist              NaN     24772321
# 3134  antagonist              NaN     24772323
#
#                                     activity_properties assay_chembl_id  \
# 1460  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5223720
# 1500  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5234756
# 1501  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5234757
# 1736  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5259720
# 1737                                                 []   CHEMBL5229099
# 1738                                                 []   CHEMBL5229098
# 1739  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4836815
# 1741                                                 []   CHEMBL4809629
# 1997                                                 []   CHEMBL5098756
# 2092                                                 []   CHEMBL5223691
# 2093                                                 []   CHEMBL5223690
# 2094                                                 []   CHEMBL5223689
# 2096                                                 []   CHEMBL5223688
# 2097  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5128722
# 2111  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5223719
# 2242  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4769734
# 2282                                                 []   CHEMBL5105877
# 2284  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4768631
# 2287  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4833465
# 2404                                                 []   CHEMBL5098762
# 2405                                                 []   CHEMBL5098761
# 2406                                                 []   CHEMBL5098760
# 2407                                                 []   CHEMBL5098759
# 2408                                                 []   CHEMBL5098758
# 3064  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4682728
# 3066  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4682730
# 3068  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4682732
# 3071                                                 []   CHEMBL4700997
# 3072                                                 []   CHEMBL4700998
# 3074                                                 []   CHEMBL5126821
# 3076                                                 []   CHEMBL5126822
# 3079  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4682726
# 3097                                                 []   CHEMBL5126823
# 3134                                                 []   CHEMBL5126824
#
#                                       assay_description assay_type  \
# 1460  Inhibition of human notum transfected with HEK...          B
# 1500      Inhibition of COX-2 (unknown origin) at 10 uM          B
# 1501      Inhibition of COX-1 (unknown origin) at 10 uM          B
# 1736  Inhibition of MMP-14 (unknown origin) using 5-...          B
# 1737                         Inhibition of human MetAP2          B
# 1738                         Inhibition of human MetAP1          B
# 1739  Inhibition of human amyloid beta (1 to 42) sel...          B
# 1741  Inhibition of self-induced amyloid beta(1 to 4...          B
# 1997               Inhibition of HDAC1 (unknown origin)          B
# 2092          Inhibition of human A3 adenosine receptor          B
# 2093         Inhibition of human A2b adenosine receptor          B
# 2094         Inhibition of human A2a adenosine receptor          B
# 2096          Inhibition of human A1 adenosine receptor          B
# 2097  Inhibition of ABCG2 (unknown origin) expressed...          B
# 2111  Inhibition of human notum using OTPS as substr...          B
# 2242  Inhibition of human plasma AChE using acetylth...          B
      NaN                     NaN  BAO_0000192  ...  NaN
#
#       type units    uo_units upper_value     value gene_symbol  \
# 1460  EC50    uM  UO_0000065         NaN     46.00       NOTUM
# 1500  IC50    uM  UO_0000065         NaN      1.10       PTGS2
# 1501  IC50    uM  UO_0000065         NaN      6.74       PTGS1
# 1736  IC50    uM  UO_0000065         NaN     26.90       MMP14
# 1737  IC50    uM  UO_0000065         NaN     80.40      METAP2
# 1738  IC50    uM  UO_0000065         NaN     84.70      METAP1
# 1739  IC50    uM  UO_0000065         NaN      9.80         APP
# 1741  IC50    uM  UO_0000065         NaN      9.80         APP
# 1997  IC50    mM  UO_0000065         NaN      0.40       HDAC1
# 2092  IC50    uM  UO_0000065         NaN     13.30      ADORA3
# 2093  IC50    uM  UO_0000065         NaN     10.40     ADORA2B
# 2094  IC50    uM  UO_0000065         NaN      9.60     ADORA2A
# 2096  IC50    uM  UO_0000065         NaN     10.70      ADORA1
# 2097  IC50    uM  UO_0000065         NaN  14000.00       ABCG2
# 2111  IC50    uM  UO_0000065         NaN     19.00       NOTUM
# 2242  IC50    uM  UO_0000065         NaN     73.30        ACHE
# 2282  IC50    uM  UO_0000065         NaN     19.01       SRSF6
# 2284  IC50    uM  UO_0000065         NaN     59.20      CYP1B1
# 2287  IC50    uM  UO_0000065         NaN     30.00         TTR
# 2404  IC50    mM  UO_0000065         NaN      1.00       HDAC6
# 2405  IC50    mM  UO_0000065         NaN      1.00       HDAC5
# 2406  IC50    mM  UO_0000065         NaN      1.00       HDAC4
# 2407  IC50    mM  UO_0000065         NaN      0.70       HDAC3
# 2408  IC50    mM  UO_0000065         NaN      0.70       HDAC2
# 3064    Ki    nM  UO_0000065         NaN  23400.00     ADORA2A
# 3066    Ki    nM  UO_0000065         NaN  33800.00     ADORA2B
# 3068    Ki    nM  UO_0000065         NaN  13300.00      ADORA3
# 3071    Ki    nM  UO_0000065         NaN  23400.00     ADORA2A
# 3072    Ki    nM  UO_0000065         NaN  20500.00     ADORA2B
# 3074    Ki    nM  UO_0000065         NaN  10700.00      ADORA1
# 3076    Ki    nM  UO_0000065         NaN  23400.00     ADORA2A
# 3079    Ki    nM  UO_0000065         NaN  10700.00      ADORA1
# 3097    Ki    nM  UO_0000065         NaN  33800.00     ADORA2B
# 3134    Ki    nM  UO_0000065         NaN  13300.00      ADORA3
#
#                                             description         parent_type  \
# 1460  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 1500  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 1501  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 1736  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 1737  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 1738  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 1739  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 1741  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 1997  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2092  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2093  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2094  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2096  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2097  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2111  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2242  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2282  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2284  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2287  Increases the conformational stability of a pr...               OTHER
# 2404  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2405  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2406  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2407  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 2408  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 3064  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
# 3066  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
# 3068  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
# 3071  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
# 3072  Negatively effects (inhibits) the normal funct...  NEGATIVE MODULATOR
# 3074  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
# 3076  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
# 3079  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
# 3097  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
# 3134  Binds to a receptor and prevents activation by...  NEGATIVE MODULATOR
#
#      activity_comment_class
# 1460               inactive
# 1500               inactive
# 1501               inactive
# 1736               inactive
# 1737               inactive
# 1738               inactive
# 1739               inactive
# 1741               inactive
# 1997               inactive
# 2092               inactive
# 2093               inactive
# 2094               inactive
# 2096               inactive
# 2097               inactive
# 2111               inactive
# 2242               inactive
# 2282               inactive
# 2284               inactive
# 2287               inactive
# 2404               inactive
# 2405               inactive
# 2406               inactive
# 2407               inactive
# 2408               inactive
# 3064               inactive
# 3066               inactive
# 3068               inactive
# 3071               inactive
# 3072               inactive
# 3074               inactive
# 3076               inactive
# 3079               inactive
# 3097               inactive
# 3134               inactive
#
# [34 rows x 50 columns]

# %%
# Update 'activity_comment_class'
final_df.loc[final_df['action_type'].isin(target_actions), 'activity_comment_class'] = final_df['action_type']
final_df
# Out:
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ... toid  \
# 5                         NaN                     NaN  BAO_0000186  ...  NaN
# 9                         NaN                     NaN  BAO_0000186  ...  NaN
# 15                        NaN                     NaN  BAO_0000186  ...  NaN
# 30                        NaN                     NaN  BAO_0000186  ...  NaN
# 31                        NaN                     NaN  BAO_0000186  ...  NaN
# ...                       ...                     ...          ...  ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...  NaN
# 3575                      NaN                     NaN  BAO_0000192  ...  NaN
# 3576                      NaN                     NaN  BAO_0000192  ...  NaN
# 3577                      NaN                     NaN  BAO_0000192  ...  NaN
# 3578                      NaN                     NaN  BAO_0000192  ...  NaN
#
#       type units    uo_units upper_value    value gene_symbol  description  \
# 5     AC50    uM  UO_0000065         NaN   1.0915         PGR          NaN
# 9     AC50    uM  UO_0000065         NaN   5.6000       HTR1A          NaN
# 15    AC50    uM  UO_0000065         NaN  25.9998        RARB          NaN
# 30    AC50   NaN         NaN         NaN      NaN      CYP1A2          NaN
# 31    AC50   NaN         NaN         NaN      NaN     CYP2C19          NaN
# ...    ...   ...         ...         ...      ...         ...          ...
# 3574    Ki   NaN         NaN         NaN      NaN      SLC6A2          NaN
# 3575    Ki   NaN         NaN         NaN      NaN     CYP2C19          NaN
# 3576    Ki   NaN         NaN         NaN      NaN      CYP2A6          NaN
# 3577    Ki   NaN         NaN         NaN      NaN       EDNRA          NaN
# 3578    Ki   NaN         NaN         NaN      NaN      ADRA2C          NaN
#
#      parent_type activity_comment_class
# 5            NaN               inactive
# 9            NaN               inactive
# 15           NaN               inactive
# 30           NaN               inactive
# 31           NaN               inactive
# ...          ...                    ...
# 3574         NaN               inactive
# 3575         NaN               inactive
# 3576         NaN               inactive
# 3577         NaN               inactive
# 3578         NaN               inactive
#
# [2172 rows x 50 columns]

# %%
final_df.activity_comment_class.value_counts()
# Out:
# activity_comment_class
# inactive      2011
# active         100
# inhibitor       33
# unknown         17
# antagonist       9
# agonist          1
# stabiliser       1
# Name: count, dtype: int64

# %%
final_df.type.value_counts()
# Out:
# type
# IC50    1065
# Ki       962
# AC50     121
# EC50      24
# Name: count, dtype: int64

# %%
final_df.standard_units.value_counts()
# Out:
# standard_units
# nM    375
# Name: count, dtype: int64

# %%
# Check for rows where one column has NaN but the other doesn't
mask = final_df['pchembl_value'].isna() ^ final_df['value'].isna()  # The ^ operator is a bitwise XOR, it returns True when the two conditions are different

rows_with_issue = final_df[mask]

print("Rows with issue:")
rows_with_issue[['value', 'pchembl_value', 'type', 'standard_units', 'activity_comment_class']].activity_comment_class.value_counts()
# Out:
# Rows with issue:
# Series([], Name: count, dtype: int64)

# %%
rows_with_issue[['standard_value', 'pchembl_value', 'type', 'standard_units', 'activity_comment_class']]
# Out:
# Empty DataFrame
# Columns: [standard_value, pchembl_value, type, standard_units, activity_comment_class]
# Index: []

# %%
final_df.columns
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value', 'gene_symbol',
#        'description', 'parent_type', 'activity_comment_class'],
#       dtype='object')

# %%
final_df
# Out:
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ... toid  \
# 5                         NaN                     NaN  BAO_0000186  ...  NaN
# 9                         NaN                     NaN  BAO_0000186  ...  NaN
# 15                        NaN                     NaN  BAO_0000186  ...  NaN
# 30                        NaN                     NaN  BAO_0000186  ...  NaN
# 31                        NaN                     NaN  BAO_0000186  ...  NaN
# ...                       ...                     ...          ...  ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...  NaN
# 3575                      NaN                     NaN  BAO_0000192  ...  NaN
# 3576                      NaN                     NaN  BAO_0000192  ...  NaN
# 3577                      NaN                     NaN  BAO_0000192  ...  NaN
# 3578                      NaN                     NaN  BAO_0000192  ...  NaN
#
#       type units    uo_units upper_value    value gene_symbol  description  \
# 5     AC50    uM  UO_0000065         NaN   1.0915         PGR          NaN
# 9     AC50    uM  UO_0000065         NaN   5.6000       HTR1A          NaN
# 15    AC50    uM  UO_0000065         NaN  25.9998        RARB          NaN
# 30    AC50   NaN         NaN         NaN      NaN      CYP1A2          NaN
# 31    AC50   NaN         NaN         NaN      NaN     CYP2C19          NaN
# ...    ...   ...         ...         ...      ...         ...          ...
# 3574    Ki   NaN         NaN         NaN      NaN      SLC6A2          NaN
# 3575    Ki   NaN         NaN         NaN      NaN     CYP2C19          NaN
# 3576    Ki   NaN         NaN         NaN      NaN      CYP2A6          NaN
# 3577    Ki   NaN         NaN         NaN      NaN       EDNRA          NaN
# 3578    Ki   NaN         NaN         NaN      NaN      ADRA2C          NaN
#
#      parent_type activity_comment_class
# 5            NaN               inactive
# 9            NaN               inactive
# 15           NaN               inactive
# 30           NaN               inactive
# 31           NaN               inactive
# ...          ...                    ...
# 3574         NaN               inactive
# 3575         NaN               inactive
# 3576         NaN               inactive
# 3577         NaN               inactive
# 3578         NaN               inactive
#
# [2172 rows x 50 columns]

# %%
final_df = final_df[final_df['activity_comment_class']!='no data']
final_df = final_df[final_df['activity_comment_class']!='unknown']
final_df
# Out:
#      action_type                                   activity_comment  \
# 5            NaN  Summarised AC50 (mean value for measurements w...
# 9            NaN  Summarised AC50 (mean value for measurements w...
# 15           NaN  Summarised AC50 (mean value for measurements w...
# 30           NaN                                           inactive
# 31           NaN                                           inactive
# ...          ...                                                ...
# 3574         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3575         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3576         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3577         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 3578         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 5        25222456                  []   CHEMBL5291861
# 9        25216321                  []   CHEMBL5291814
# 15       25211862                  []   CHEMBL5291875
# 30        6060231                  []   CHEMBL1741322
# 31        6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 3574      7604341                  []   CHEMBL1909094
# 3575      7644185                  []   CHEMBL1909134
# 3576      7644183                  []   CHEMBL1909133
# 3577      7644205                  []   CHEMBL1909144
# 3578      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 5     Antagonist activity at human PGR in an in vitr...          F
# 9     Antagonist activity at human HTR1A in an in vi...          F
# 15    Antagonist activity at human RARB in an in vit...          F
# 30    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 31    PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 3574  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 3575  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 3576  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 3577  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 3578  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ... toid  \
# 5                         NaN                     NaN  BAO_0000186  ...  NaN
# 9                         NaN                     NaN  BAO_0000186  ...  NaN
# 15                        NaN                     NaN  BAO_0000186  ...  NaN
# 30                        NaN                     NaN  BAO_0000186  ...  NaN
# 31                        NaN                     NaN  BAO_0000186  ...  NaN
# ...                       ...                     ...          ...  ...  ...
# 3574                      NaN                     NaN  BAO_0000192  ...  NaN
# 3575                      NaN                     NaN  BAO_0000192  ...  NaN
# 3576                      NaN                     NaN  BAO_0000192  ...  NaN
# 3577                      NaN                     NaN  BAO_0000192  ...  NaN
# 3578                      NaN                     NaN  BAO_0000192  ...  NaN
#
#       type units    uo_units upper_value    value gene_symbol  description  \
# 5     AC50    uM  UO_0000065         NaN   1.0915         PGR          NaN
# 9     AC50    uM  UO_0000065         NaN   5.6000       HTR1A          NaN
# 15    AC50    uM  UO_0000065         NaN  25.9998        RARB          NaN
# 30    AC50   NaN         NaN         NaN      NaN      CYP1A2          NaN
# 31    AC50   NaN         NaN         NaN      NaN     CYP2C19          NaN
# ...    ...   ...         ...         ...      ...         ...          ...
# 3574    Ki   NaN         NaN         NaN      NaN      SLC6A2          NaN
# 3575    Ki   NaN         NaN         NaN      NaN     CYP2C19          NaN
# 3576    Ki   NaN         NaN         NaN      NaN      CYP2A6          NaN
# 3577    Ki   NaN         NaN         NaN      NaN       EDNRA          NaN
# 3578    Ki   NaN         NaN         NaN      NaN      ADRA2C          NaN
#
#      parent_type activity_comment_class
# 5            NaN               inactive
# 9            NaN               inactive
# 15           NaN               inactive
# 30           NaN               inactive
# 31           NaN               inactive
# ...          ...                    ...
# 3574         NaN               inactive
# 3575         NaN               inactive
# 3576         NaN               inactive
# 3577         NaN               inactive
# 3578         NaN               inactive
#
# [2155 rows x 50 columns]

# %%
final_df = final_df.reset_index(drop=True)
final_df.to_csv("Binding_activities_chembl_mitotox_cleaned.csv.gz", index=False, compression='gzip')

# %%
final_df
# Out:
#      action_type                                   activity_comment  \
# 0            NaN  Summarised AC50 (mean value for measurements w...
# 1            NaN  Summarised AC50 (mean value for measurements w...
# 2            NaN  Summarised AC50 (mean value for measurements w...
# 3            NaN                                           inactive
# 4            NaN                                           inactive
# ...          ...                                                ...
# 2150         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 2151         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 2152         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 2153         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
# 2154         NaN  Not Active (inhibition < 50% @ 10 uM and thus ...
#
#       activity_id activity_properties assay_chembl_id  \
# 0        25222456                  []   CHEMBL5291861
# 1        25216321                  []   CHEMBL5291814
# 2        25211862                  []   CHEMBL5291875
# 3         6060231                  []   CHEMBL1741322
# 4         6052876                  []   CHEMBL1741323
# ...           ...                 ...             ...
# 2150      7604341                  []   CHEMBL1909094
# 2151      7644185                  []   CHEMBL1909134
# 2152      7644183                  []   CHEMBL1909133
# 2153      7644205                  []   CHEMBL1909144
# 2154      7676247                  []   CHEMBL1909090
#
#                                       assay_description assay_type  \
# 0     Antagonist activity at human PGR in an in vitr...          F
# 1     Antagonist activity at human HTR1A in an in vi...          F
# 2     Antagonist activity at human RARB in an in vit...          F
# 3     PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# 4     PUBCHEM_BIOASSAY: Cytochrome panel assay with ...          F
# ...                                                 ...        ...
# 2150  DRUGMATRIX: Norepinephrine Transporter radioli...          B
# 2151  DRUGMATRIX: CYP450, 2C19 enzyme inhibition (su...          B
# 2152  DRUGMATRIX: CYP450, 2A6 enzyme inhibition (sub...          B
# 2153  DRUGMATRIX: Endothelin ETA radioligand binding...          B
# 2154  DRUGMATRIX: Adrenergic Alpha-2C radioligand bi...          B
#
#       assay_variant_accession  assay_variant_mutation bao_endpoint  ... toid  \
# 0                         NaN                     NaN  BAO_0000186  ...  NaN
# 1                         NaN                     NaN  BAO_0000186  ...  NaN
# 2                         NaN                     NaN  BAO_0000186  ...  NaN
# 3                         NaN                     NaN  BAO_0000186  ...  NaN
# 4                         NaN                     NaN  BAO_0000186  ...  NaN
# ...                       ...                     ...          ...  ...  ...
# 2150                      NaN                     NaN  BAO_0000192  ...  NaN
# 2151                      NaN                     NaN  BAO_0000192  ...  NaN
# 2152                      NaN                     NaN  BAO_0000192  ...  NaN
# 2153                      NaN                     NaN  BAO_0000192  ...  NaN
# 2154                      NaN                     NaN  BAO_0000192  ...  NaN
#
#       type units    uo_units upper_value    value gene_symbol  description  \
# 0     AC50    uM  UO_0000065         NaN   1.0915         PGR          NaN
# 1     AC50    uM  UO_0000065         NaN   5.6000       HTR1A          NaN
# 2     AC50    uM  UO_0000065         NaN  25.9998        RARB          NaN
# 3     AC50   NaN         NaN         NaN      NaN      CYP1A2          NaN
# 4     AC50   NaN         NaN         NaN      NaN     CYP2C19          NaN
# ...    ...   ...         ...         ...      ...         ...          ...
# 2150    Ki   NaN         NaN         NaN      NaN      SLC6A2          NaN
# 2151    Ki   NaN         NaN         NaN      NaN     CYP2C19          NaN
# 2152    Ki   NaN         NaN         NaN      NaN      CYP2A6          NaN
# 2153    Ki   NaN         NaN         NaN      NaN       EDNRA          NaN
# 2154    Ki   NaN         NaN         NaN      NaN      ADRA2C          NaN
#
#      parent_type activity_comment_class
# 0            NaN               inactive
# 1            NaN               inactive
# 2            NaN               inactive
# 3            NaN               inactive
# 4            NaN               inactive
# ...          ...                    ...
# 2150         NaN               inactive
# 2151         NaN               inactive
# 2152         NaN               inactive
# 2153         NaN               inactive
# 2154         NaN               inactive
#
# [2155 rows x 50 columns]

# %%
final_df.canonical_smiles.nunique()
# Out:
# 30

# %%
final_df.parent_molecule_chembl_id.nunique()
# Out:
# 30

# %%
final_df.gene_symbol.nunique()
# Out:
# 170

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by 'activity_comment_class' and get unique 'chembl_id's for each class
unique_chembl_counts = final_df.groupby('activity_comment_class')['parent_molecule_chembl_id'].nunique()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x=unique_chembl_counts.index, y=unique_chembl_counts.values)
plt.title('Number of Unique Chembl IDs in Each Activity Comment Class')
plt.ylabel('Number of Unique Chembl IDs')
plt.xlabel('Activity Comment Class')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
for gene in final_df.gene_symbol.unique():
    
    df = final_df[final_df['gene_symbol']==gene]
    print(df.activity_comment_class.value_counts())
# Out:
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    24
# active       4
# Name: count, dtype: int64
# activity_comment_class
# inactive    28
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    31
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    29
# Name: count, dtype: int64
# activity_comment_class
# inactive    30
# Name: count, dtype: int64
# activity_comment_class
# inactive    26
# Name: count, dtype: int64
# activity_comment_class
# inactive    9
# Name: count, dtype: int64
# activity_comment_class
# inactive      25
# antagonist     2
# inhibitor      1
# Name: count, dtype: int64
# activity_comment_class
# inactive      27
# antagonist     2
# inhibitor      1
# Name: count, dtype: int64
# activity_comment_class
# inactive    11
# Name: count, dtype: int64
# activity_comment_class
# inactive     22
# active       13
# inhibitor     2
# Name: count, dtype: int64
# activity_comment_class
# inactive    3
# Name: count, dtype: int64
# activity_comment_class
# inactive    3
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# Name: count, dtype: int64
# activity_comment_class
# inactive    23
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive     22
# inhibitor     1
# Name: count, dtype: int64
# activity_comment_class
# inactive    26
# Name: count, dtype: int64
# activity_comment_class
# inactive    24
# Name: count, dtype: int64
# activity_comment_class
# inactive     8
# inhibitor    1
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# Name: count, dtype: int64
# activity_comment_class
# inactive      29
# antagonist     3
# inhibitor      1
# Name: count, dtype: int64
# activity_comment_class
# inactive     20
# active       12
# inhibitor     1
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# active    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    23
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    22
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# active       2
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# active       2
# Name: count, dtype: int64
# activity_comment_class
# inactive    22
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# Name: count, dtype: int64
# activity_comment_class
# inactive     19
# active       15
# inhibitor     4
# Name: count, dtype: int64
# activity_comment_class
# inactive    23
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# active       2
# Name: count, dtype: int64
# activity_comment_class
# inactive    22
# Name: count, dtype: int64
# activity_comment_class
# inactive    21
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# active       4
# agonist      1
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    3
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    4
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive      1
# stabiliser    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# active      1
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# active      1
# Name: count, dtype: int64
# activity_comment_class
# active      1
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# active       2
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    19
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# active       1
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    20
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# active      1
# Name: count, dtype: int64
# activity_comment_class
# active    7
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    2
# inactive     1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# active      4
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# active      4
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive     4
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inactive      10
# inhibitor      2
# antagonist     2
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# active    1
# Name: count, dtype: int64
# activity_comment_class
# active      2
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# active    1
# Name: count, dtype: int64
# activity_comment_class
# active    1
# Name: count, dtype: int64
# activity_comment_class
# active       1
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inhibitor    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    7
# active      1
# Name: count, dtype: int64
# activity_comment_class
# active    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    2
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# active    3
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64
# activity_comment_class
# inactive    1
# Name: count, dtype: int64

# %%
final_df.parent_molecule_chembl_id.value_counts()[:25]
# Out:
# parent_molecule_chembl_id
# CHEMBL113        239
# CHEMBL549        226
# CHEMBL139        218
# CHEMBL109        201
# CHEMBL106        195
# CHEMBL565        190
# CHEMBL1566       189
# CHEMBL515        188
# CHEMBL959        181
# CHEMBL154111     178
# CHEMBL1324        25
# CHEMBL681         15
# CHEMBL497         14
# CHEMBL1095777     10
# CHEMBL1289494     10
# CHEMBL1201256     10
# CHEMBL1622         8
# CHEMBL22373        8
# CHEMBL562318       7
# CHEMBL132767       6
# CHEMBL279678       6
# CHEMBL1111         5
# CHEMBL1518572      5
# CHEMBL1043         4
# CHEMBL3218575      4
# Name: count, dtype: int64

# %%
final_df.activity_comment.value_counts()
# Out:
# activity_comment
# Not Active (inhibition < 50% @ 10 uM and thus dose-reponse curve not measured)                                                   1758
# Summarised AC50 (mean value for measurements with a relation sign "="; largest value for measurements with relation sign ">")      84
# inactive                                                                                                                           29
# Active                                                                                                                              7
# Note: corresponding IC50 reported as Active                                                                                         2
# active                                                                                                                              2
# Not Active                                                                                                                          1
# inhibitor [IC50=4uM]                                                                                                                1
# 353651                                                                                                                              1
# 353645                                                                                                                              1
# 328818                                                                                                                              1
# 328022                                                                                                                              1
# 273499                                                                                                                              1
# 273491                                                                                                                              1
# 273495                                                                                                                              1
# inhibitor [IC50=4.5uM]                                                                                                              1
# 328085                                                                                                                              1
# 353639                                                                                                                              1
# Name: count, dtype: int64

# %%
final_df.pchembl_value.hist()
# Out:
# <Axes: >

# %%
final_df.gene_symbol.value_counts()
# Out:
# gene_symbol
# SLC6A4     38
# PTGS2      37
# PTGS1      33
# ADORA2A    33
# CYP3A4     32
#            ..
# MPO         1
# FLT4        1
# AKR1A1      1
# ABCB1       1
# GDA         1
# Name: count, Length: 170, dtype: int64

# %%
final_df.standard_type.value_counts()
# Out:
# standard_type
# IC50    1053
# Ki       957
# AC50     121
# EC50      24
# Name: count, dtype: int64

# %%
final_df.standard_units.value_counts()
# Out:
# standard_units
# nM    366
# Name: count, dtype: int64
